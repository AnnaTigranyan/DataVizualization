# %% [markdown]
# # Homework 3
#
# ## Anna Tigranyan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing data

# %%
df = pd.read_csv(r'character-predictions.csv')

# %%
df.head()
# Out:
#    S.No  actual  pred  alive   plod                  name  \
# 0     1       0     0  0.054  0.946  Viserys II Targaryen
# 1     2       1     0  0.387  0.613           Walder Frey
# 2     3       1     0  0.493  0.507          Addison Hill
# 3     4       0     0  0.076  0.924           Aemma Arryn
# 4     5       1     1  0.617  0.383        Sylva Santagar
#
#                   title  male   culture  dateOfBirth  ...  isAliveHeir  \
# 0                   NaN     1       NaN          NaN  ...          0.0
# 1  Lord of the Crossing     1  Rivermen        208.0  ...          NaN
# 2                   Ser     1       NaN          NaN  ...          NaN
# 3                 Queen     0       NaN         82.0  ...          NaN
# 4            Greenstone     0   Dornish        276.0  ...          NaN
#
#   isAliveSpouse isMarried isNoble   age numDeadRelations  boolDeadRelations  \
# 0           NaN         0       0   NaN               11                  1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No               1946 non-null   int64
#  1   actual             1946 non-null   int64
#  2   pred               1946 non-null   int64
#  3   alive              1946 non-null   float64
#  4   plod               1946 non-null   float64
#  5   name               1946 non-null   object
#  6   title              938 non-null    object
#  7   male               1946 non-null   int64
#  8   culture            677 non-null    object
#  9   dateOfBirth        433 non-null    float64
#  10  DateoFdeath        444 non-null    float64
#  11  mother             21 non-null     object
#  12  father             26 non-null     object
#  13  heir               23 non-null     object
#  14  house              1519 non-null   object
#  15  spouse             276 non-null    object
# ...

# %%
df1 = df.loc[abs(df['age'])<100]

# %%
x = df1['age']  # Sample data.

fig, ax = plt.subplots(figsize=(8,5), constrained_layout=True,dpi=80)
ax.plot(x, x, label='linear',color='crimson',linestyle=(0,(5,10)),linewidth=3)  # Plot some data on the axes.
ax.set_facecolor('azure')
# colering and linewidths of x and y axes 
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(5)
    ax.spines[axis].set_color("indigo")
    
for axi in ['top','right']:  
    ax.spines[axi].set_color(None)  
    

ax.set_ylabel('Age',color ='crimson',size = "18") # Add an y-label to the axes.
ax.set_xlabel('Age',color ='crimson',size = "18")  # Add an x-label to the axes.   
ax.set_title("Simple Plot  of 'Age'",fontsize = 25, color = 'indigo', backgroundcolor = 'lavender')  # Add a title to the axes.
;
# Out:
# ''

# %%
x = df['popularity']  # Sample data.

fig, ax = plt.subplots(figsize=(8,5), constrained_layout=True,dpi=80,facecolor='bisque')
ax.plot(x, x, label='linear',color='lime',linestyle=(0,(1,1)),linewidth=4)  # Plot some data on the axes.

# colering and linewidths of x and y axes 
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(5)
    ax.spines[axis].set_color("orange")
    
for axi in ['top','right']:  
    ax.spines[axi].set_color('green')  
    

ax.set_ylabel('popularity',color ='green',size = "18") # Add an y-label to the axes.
ax.set_xlabel('popularity',color ='green',size = "18")  # Add an x-label to the axes.   
ax.set_title("Simple Plot  of 'popularity'",fontsize = 25,loc='left', 
             color = 'green', backgroundcolor = 'honeydew')  # Add a title to the axes.
;
# Out:
# ''

# %%
#Take data points where the absolute values of the ages are less than 100
df1 = df.loc[abs(df['age'])<100] 

fig, ax = plt.subplots(figsize = (8,5),dpi=100,facecolor="beige")
# Connection between age and popularity(scatter plot):


ax.scatter(x=df1['age'],y=df1['popularity'],color='cyan',edgecolors='green',
                linewidths=2,marker = 'p')

ax.set_title('Popularity by age',fontsize = 25, color = 'green', backgroundcolor = 'honeydew')# Add a title to the axes.
ax.set_ylabel('Popularity',color ='green',size = "15") # Add a y-label to the axes.
ax.set_xlabel('Age',color ='Green',size = "15") # Add a x-label to the axes.

# colering and linewidths of x and y axes 

for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(5)
    ax.spines[axis].set_color("indigo")
for axi in ['top','right']:  
    ax.spines[axi].set_color(None)

# %%
# groupby houeses
groups = df[df['popularity']>0.6].groupby('house')

fig, ax = plt.subplots(figsize = (12,8))
ax.margins(0.09)

i = 0 # for color
for name, group in groups:
    # for each group plotting point which represents number of Dead Relations by age
    t = ax.plot(group.age, group.numDeadRelations, marker='o', linestyle='', ms=20, label=name, alpha = 0.8)
    t[0].set_linestyle('solid')
    i += 1 # changing color
#set legends    
ax.legend(loc = 'upper right', fontsize = 10, title = 'Houses')
#set labels
ax.set_xlabel('Age',fontsize = 20, color = 'r', backgroundcolor = 'bisque')
ax.set_ylabel('Number of Dead Relatives', fontsize = 20, color = 'r', backgroundcolor = 'bisque')
#set title
ax.set_title('Houses with maximum death',fontsize = 20, color = 'r', backgroundcolor = 'bisque')

#colorinf and linewidth of axes
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
    ax.spines[axis].set_color('orangered')

;
# Out:
# ''

# %%
# Pie chart

labels = 'NO', 'Yes'
x = df['isMarried'].value_counts()

fig, ax = plt.subplots(figsize = (5,5),dpi=100)

ax.pie(x, labels=labels, autopct='%1.0f%%',shadow=True, startangle=100,
       colors=['tomato','gold'],radius=0.5)

ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax.legend(['Yes','No'])
ax.set_title('Pie plot of "isMarried"', color = 'darkorange',fontsize = 20)
;
# Out:
# ''

# %%
# Pie chart

labels = 'NO', 'Yes'
x = df['isNoble'].value_counts()

fig, ax = plt.subplots(figsize = (5,5),dpi=100)
explode = (0.05, 0)
ax.pie(x, labels=labels,explode=explode,
       autopct='%1.0f%%',shadow=True, startangle=80,
       colors=['teal','orchid'],radius=1)

ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax.legend(['Yes','No'])
ax.set_title('Pie plot of "isNoble"', color = 'purple', backgroundcolor = 'honeydew',fontsize = 20)
;
# Out:
# ''

# %%
x = df['title'].value_counts()[:6] #choosing top 6 titles by count

labels = [] # titles names 
for row in x.index:
    labels.append(row)
    
# Pie chart

fig, ax = plt.subplots(figsize = (5,5),dpi=100)
explode = (0.1, 0.05,0.05,0.05,0.05,0.05)
ax.pie(x, labels=labels,explode=explode,
       autopct='%1.0f%%',shadow=True, startangle=40,radius=1)

ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax.legend(['Yes','No'])
ax.set_title('Pie plot of "Titles"', color = 'indigo',fontsize = 20)
;
# Out:
# ''

# %%
np.random.seed(196808012)

x = df['title'].value_counts()[:5] #choosing top 5 titles by count

labels = [] # titles names 
for row in x.index:
    labels.append(row)

fig, ax = plt.subplots(figsize=(10,6),dpi=80,facecolor="lavender")
ax.bar(labels, x, color = ['purple', 'lightblue', 'blueviolet', 'pink', 'indigo']);

ax.set_title('Counts of top titles',fontsize = 25, color = 'indigo')# Add a title to the axes.
ax.set_ylabel('Count',color ='indigo',size = "20") # Add a y-label to the axes.
ax.set_xlabel('titles',color ='indigo',size = "20") # Add a x-label to the axes.

# colering and linewidths of x and y axes 

for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines[axis].set_color("indigo")
for axi in ['top','right']:  
    ax.spines[axi].set_color(None)

# %%
np.random.seed(196808012)

x = df['title'].value_counts()[:20] #choosing top 20 titles by count

labels = [] # titles names 
for row in x.index:
    labels.append(row)

fig, ax = plt.subplots(figsize=(10,6),dpi=80)
ax.set_facecolor("lavender")
ax.barh(labels, x, color = ['purple', 'lightblue', 'blueviolet', 'pink', 'crimson']);

ax.set_title('Counts of top titles',fontsize = 25, color = 'crimson')# Add a title to the axes.
ax.set_ylabel('Titles',color ='indigo',size = "20") # Add a y-label to the axes.
ax.set_xlabel('Count',color ='indigo',size = "20") # Add a x-label to the axes.

# colering and linewidths of x and y axes 

for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
    ax.spines[axis].set_color("indigo")
for axi in ['top','right']:  
    ax.spines[axi].set_color(None)

# %%
fig, axs = plt.subplots(1,2,figsize=(10,6),dpi=100)

axs[0].scatter(x=df1['popularity'],y=df1['age'],color='gold',edgecolors='red',
                linewidths=2,marker = 'o')
axs[1].scatter(x=df1['alive'],y=df1['age'],color='lavender',edgecolors='blue',
                linewidths=2,marker = 'h')
# set labels
axs[0].set_xlabel('popularity',color ='red',size = "20",backgroundcolor = 'bisque') 
axs[0].set_ylabel('Age')  
axs[1].set_xlabel('alive',color ='indigo',size = "20",backgroundcolor = "lavender")

axs[1].set_yticks([]) # don't show y ticks for second plot


# colering and linewidths of x and y axes 

# for left plot
for axis in ['bottom','left']:
    axs[0].spines[axis].set_linewidth(3)
    axs[0].spines[axis].set_color("brown")    
for axi in ['top','right']:  
    axs[0].spines[axi].set_color(None)
    
#for right plot    
for axis in ['bottom','right']: 
    axs[1].spines[axis].set_linewidth(3)
    axs[1].spines[axis].set_color("indigo")        
for axi in ['top','left']: 
    axs[1].spines[axi].set_color(None)
;
# Out:
# ''

# %%
np.linspace(0, 2, 100)
fig, axd = plt.subplot_mosaic([['upleft', 'right'],
                               ['lowleft', 'right']],
                               figsize=(10,6),dpi=100)


# scatter plots
axd['upleft'].scatter(x=df1['popularity'],y=df1['age'],color='gold',edgecolors='red',
                linewidths=2,marker = 'o')
axd['lowleft'].scatter(x=df1['alive'],y=df1['age'],color='lavender',edgecolors='blue',
                linewidths=2,marker = 'h')
axd['right'].scatter(x=df1['alive'],y=df1['popularity'],color='lime',edgecolors='green',
                linewidths=2,marker = 'h')

# set labels

axd['upleft'].set_xlabel('popularity',color ='red',size = "15",backgroundcolor = 'bisque') 
axd['upleft'].set_ylabel('Age',color ='red',size = "15",backgroundcolor = 'bisque')

axd['lowleft'].set_xlabel('alive',color ='indigo',size = "15",backgroundcolor = "lavender")
axd['lowleft'].set_ylabel('Age',color ='indigo',size = "15",backgroundcolor = "lavender")

axd['right'].set_xlabel('alive',color ='green',size = "15",backgroundcolor = 'honeydew')
axd['right'].set_ylabel('popularity',color ='green',size = "15",backgroundcolor = 'honeydew')



# colering and linewidths of x and y axes 

# for upleft plot
for axis in ['bottom','left']:
    axd['upleft'].spines[axis].set_linewidth(3)
    axd['upleft'].spines[axis].set_color("brown")    
for axi in ['top','right']:  
    axd['upleft'].spines[axi].set_color(None)
    
#for lowleft plot    
for axis in ['bottom','left']: 
    axd['lowleft'].spines[axis].set_linewidth(3)
    axd['lowleft'].spines[axis].set_color("indigo")        
for axi in ['top','right']: 
    axd['lowleft'].spines[axi].set_color(None)
    
#for right plot    
for axis in ['bottom','left']: 
    axd['right'].spines[axis].set_linewidth(3)
    axd['right'].spines[axis].set_color("olive")        
for axi in ['top','right']: 
    axd['right'].spines[axi].set_color(None)

# %%
# data
x = df['popularity']

fig, ax = plt.subplots(figsize=(10, 5),dpi=100)
# histogram
n, bins, patches = ax.hist(x, 50, histtype ='bar',density = 1,color = 'violet',alpha = 0.7)

# labels
ax.set_xlabel('Popularity')

# Set title
ax.set_title('Histogram of "Popularity" ',fontsize = 20, color = 'indigo', backgroundcolor = 'thistle')

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
    ax.spines[axis].set_color("navy")

;
# Out:
# ''

# %%
# data
x = df1['age']

fig, ax = plt.subplots(figsize=(10, 5),dpi=100,facecolor='silver')
ax.set_facecolor("grey")
# histogram
n, bins, patches = ax.hist(x, 50, histtype='step',density = 1,color = 'white',alpha = 0.7,linewidth=5)

# labels
ax.set_xlabel('Age',color ='red',size = "15",backgroundcolor = 'bisque')

# Set title
ax.set_title('Histogram of "Age" ',fontsize = 20, color = 'r', backgroundcolor = 'bisque')

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
    ax.spines[axis].set_color('r')

;
# Out:
# ''

# %%
# data
x = df['popularity']
y = df['alive']

fig, ax = plt.subplots(figsize=(10, 5),dpi=100,facecolor='lavenderblush')
ax.set_facecolor("lavenderblush")
# histogram
n, bins, patches = ax.hist([x,y], 50, histtype='bar',density = 1,
                           color = ['indigo','crimson'],alpha = 0.7,
                           linewidth=5,label=['popularity', 'alive'])

# Set title
ax.set_title('Histograms of "popularity" and "alive" ',fontsize = 20, color = 'crimson', backgroundcolor = 'white')
ax.legend()
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
    ax.spines[axis].set_color(None)

;
# Out:
# ''

# %%
x=df['popularity']
fig, ax = plt.subplots(figsize=(10, 5),dpi=100,facecolor='palegreen')

c = dict(markerfacecolor='lime', marker='h')
ax.boxplot(x,flierprops=c,showmeans=True)


ax.set_title('BoxPlot of "popularity" ',fontsize = 20, color = 'green', backgroundcolor = 'white')
;
# Out:
# ''

# %%
x=df['alive']
fig, ax = plt.subplots(figsize=(10, 5),dpi=100,facecolor='plum')

c = dict(markerfacecolor='lime', marker='h')
ax.boxplot(x,flierprops=c,showmeans=True,vert=False)


ax.set_title('BoxPlot of "alive" ',fontsize = 20, color = 'purple', backgroundcolor = 'white')
;
# Out:
# ''

# %%
fig, ax = plt.subplots(figsize=(10, 5),dpi=100,facecolor='bisque')
box = ax.boxplot([df["popularity"], df1["alive"]], showfliers=False,
                 vert=False, patch_artist=True,
                medianprops={"color": "white", "linewidth": 1},
                boxprops={"facecolor": "pink", "edgecolor": "white",
                          "linewidth": 0.5});

# fill with colors
colors = ['gold', 'lime']
for bplot in box:
    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)
        

    
ax.yaxis.grid(True)
ax.set_title('BoxPlots of "popularity" and "alive" ',fontsize = 20, color = 'r')

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
    ax.spines[axis].set_color('orangered')
